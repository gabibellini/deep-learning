# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cu118

# %%
#vamo vê

tns = torch.randn(10)
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print(device)
# Out:
# cuda

# %%
# criar um tensor aleatório - dimensionalidade 7 x 7 x 3
# criar outro tensor        - dimensionalidade 147 x 1
# somar tensores modificando apenas o primeiro tensor

tns1 = torch.randn([7,7,3])
tns2 = torch.randn([147, 1])

print(tns1.shape)
print(tns2.shape)
# Out:
# torch.Size([7, 7, 3])
# torch.Size([147, 1])

# %%
tnst = tns1.view(-1,1) + tns2
print(tnst)
# Out:
# tensor([[-6.9146e-01],
#         [ 2.2137e+00],
#         [ 1.2293e-01],
#         [-1.5517e+00],
#         [ 1.6501e-01],
#         [ 6.1840e-01],
#         [ 3.0317e+00],
#         [-2.3744e+00],
#         [ 1.9259e+00],
#         [-6.3724e-01],
#         [-1.0195e-01],
#         [-1.4409e+00],
#         [-5.3533e-01],
#         [ 4.2137e-01],
#         [-8.4695e-01],
#         [-2.1354e+00],
#         [ 9.0445e-01],
#         [ 5.6281e-01],
#         [-2.9698e-01],
#         [-1.5407e-01],
#         [-4.7357e-01],
#         [ 3.4104e-01],
#         [ 1.1263e-01],
#         [-5.5170e-01],
#         [-1.9886e+00],
#         [-3.1114e-01],
#         [ 2.4662e+00],
#         [ 1.6812e+00],
#         [ 1.7663e+00],
#         [ 6.8525e-01],
#         [-6.2851e-02],
#         [ 8.4103e-01],
#         [-8.3087e-01],
#         [-1.1819e+00],
#         [ 1.0277e+00],
#         [-4.0341e-01],
#         [ 7.7318e-01],
#         [ 1.1490e+00],
#         [-2.5960e-01],
#         [-1.4066e-01],
# ...
